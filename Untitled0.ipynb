# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
#  효도원/
#  컴공특/
#  1.경진대회/
#  aibig.zip
# 'B반 저녁식사.gsheet'
# 'Colab Notebooks'/
#  deepracer-k1999-race-lines-master/
#  김효림_연구인턴_이력서.docx
# 'IMG_5672 (1).MOV'
#  IMG_5672.MOV
#  Lucidchart/
#  김효림_성적증명서.pdf
#  김효림_졸업예정증명서.pdf
#  song.zip
#  _talkv_wpOBmbzysK_gHrQpDoj0GxD7yVgDKo2Rk_talkv_high.mp4
#  test.csv
#  train.csv
# 'Untitled Diagram.drawio'

# %%
cd deepracer-k1999-race-lines-master
# Out:
# /content/drive/MyDrive/deepracer-k1999-race-lines-master

# %%
ls
# Out:
# deepracer-k1999-race-lines-master/

# %%
cd deepracer-k1999-race-lines-master/
# Out:
# /content/drive/MyDrive/deepracer-k1999-race-lines-master/deepracer-k1999-race-lines-master

# %%
ls
# Out:
# assets/  Race-Line-Calculation.ipynb  README.md  Untitled0.ipynb
# LICENSE  racelines/                   tracks/
